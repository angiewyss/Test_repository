# %%
4+3
# Out:
# 7

# %%
a=7

# %%
a
# Out:
# 7

# %% [markdown]
# # Angie's 1st Jupyter Script

# %% [markdown]
# ## This is a subtitle

# %% [markdown]
# - this
# - is a
# - list

# %% [markdown]
# this is an email adress angela.wyss@hotmail.com

# %% [markdown]
# ## test some python

# %% [markdown]
# import some libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
gauss= np.random.randn(100)

# %%
plt.plot(gauss)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
